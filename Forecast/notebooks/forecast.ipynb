# %%
import sys
import os

sys.path.insert(0, os.path.abspath("."))

from pipeline.runner import run_full_pipeline

# %%
df = run_full_pipeline(
    r'C:\Users\Normc\OneDrive\Рабочий стол\Python\Работа\Forecast\data\raw\Запчасти списанные в ремонт.xlsx',
    r'C:\Users\Normc\OneDrive\Рабочий стол\Python\Работа\Forecast\data\raw\Остатки и обороты.xlsx'
)

# %%
import streamlit as st
print(st.__version__)
# Out:
# 1.55.0
